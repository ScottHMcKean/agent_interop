# %% [markdown]
# # Lakebase + Registry Setup
#
# This notebook uses Databricks Connect and the Databricks SDK to:
#
# - Create a Lakebase (database) instance.
# - Create a `shm.agent_registry` schema in Unity Catalog for visibility.
# - Create the registry tables inside the Lakebase database.
#
# It authenticates using the Databricks workspace client, so no explicit host/token is needed if your Databricks Connect profile is configured.

# %%
from databricks.connect import DatabricksSession
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.database import DatabaseInstance
from pathlib import Path
import json
import psycopg
import re
import yaml

config_path = Path("config.yaml")
if not config_path.exists():
    config_path = Path("..") / "config.yaml"
if not config_path.exists():
    raise RuntimeError("Missing config.yaml")

config = yaml.safe_load(config_path.read_text(encoding="utf-8")) or {}
if not isinstance(config, dict):
    raise RuntimeError("config.yaml must be a flat dictionary")

CATALOG = config.get("catalog", "shm")
REGISTRY_SCHEMA = config.get("registry_schema", "agent_registry")
LAKEBASE_INSTANCE_NAME = config.get("lakebase_instance_name", "agent-registry")
LAKEBASE_CAPACITY = config.get("lakebase_capacity", "CU_1")
LAKEBASE_RETENTION_DAYS = int(config.get("lakebase_retention_days", 7))

LAKEBASE_DSN = config.get("lakebase_dsn")
LAKEBASE_HOST = config.get("lakebase_host")
LAKEBASE_DB = config.get("lakebase_db", "databricks_postgres")
DEFAULT_MCP_SERVER_URL = config.get("default_mcp_server_url")
A2A_BASE_URL = config.get("a2a_base_url", "/api/a2a")

# %%
w = WorkspaceClient()

existing = None
for inst in w.database.list_database_instances():
    if inst.name == LAKEBASE_INSTANCE_NAME:
        existing = inst
        break

if existing:
    instance = existing
else:
    w.database.create_database_instance(
        DatabaseInstance(
            name=LAKEBASE_INSTANCE_NAME,
            capacity=LAKEBASE_CAPACITY,
            retention_window_in_days=LAKEBASE_RETENTION_DAYS,
        )
    )
    instance = None
    for inst in w.database.list_database_instances():
        if inst.name == LAKEBASE_INSTANCE_NAME:
            instance = inst
            break

if not instance:
    raise RuntimeError("Lakebase instance not found after create.")

print(f"Lakebase instance: {instance.name}")
print(f"Read/write endpoint: {instance.read_write_dns}")
# Out:
# Lakebase instance: agent-registry
# Read/write endpoint: instance-4abc793a-34e7-49ea-aec3-e35f9ebefb2e.database.azuredatabricks.net

# %%
builder = DatabricksSession.builder
spark = builder.serverless().getOrCreate()

spark.sql(f"CREATE CATALOG IF NOT EXISTS {CATALOG}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {CATALOG}.{REGISTRY_SCHEMA}")
print(f"Ensured UC schema: {CATALOG}.{REGISTRY_SCHEMA}")
# Out:
# Ensured UC schema: shm.agent_registry

# %%
from urllib.parse import quote_plus

lakebase_dsn = LAKEBASE_DSN
if not lakebase_dsn:
    ws = WorkspaceClient()
    token = ws.config.oauth_token().access_token
    user = ws.current_user.me().user_name

    host = LAKEBASE_HOST or instance.read_write_dns
    if ":" in host:
        host, port = host.split(":", 1)
    else:
        port = "5432"

    lakebase_dsn = (
        "postgresql://"
        f"{quote_plus(user)}:{quote_plus(token)}@{host}:{port}/{LAKEBASE_DB}"
        "?sslmode=require"
    )

create_sql = f"""
CREATE SCHEMA IF NOT EXISTS {REGISTRY_SCHEMA};

CREATE TABLE IF NOT EXISTS {REGISTRY_SCHEMA}.agents (
    agent_id TEXT PRIMARY KEY,
    name TEXT,
    description TEXT,
    owner TEXT,
    status TEXT,
    default_version TEXT,
    created_at TIMESTAMPTZ DEFAULT now(),
    updated_at TIMESTAMPTZ DEFAULT now()
);

CREATE TABLE IF NOT EXISTS {REGISTRY_SCHEMA}.agent_versions (
    agent_id TEXT NOT NULL,
    version TEXT NOT NULL,
    mcp_server_url TEXT,
    llm_endpoint_name TEXT,
    system_prompt TEXT,
    tags JSONB,
    created_at TIMESTAMPTZ DEFAULT now(),
    updated_at TIMESTAMPTZ DEFAULT now(),
    PRIMARY KEY (agent_id, version),
    FOREIGN KEY (agent_id) REFERENCES {REGISTRY_SCHEMA}.agents(agent_id)
);

CREATE TABLE IF NOT EXISTS {REGISTRY_SCHEMA}.agent_protocol_cards (
    agent_id TEXT NOT NULL,
    version TEXT NOT NULL,
    protocol TEXT NOT NULL,
    card_json JSONB,
    updated_at TIMESTAMPTZ DEFAULT now(),
    PRIMARY KEY (agent_id, version, protocol),
    FOREIGN KEY (agent_id, version) REFERENCES {REGISTRY_SCHEMA}.agent_versions(agent_id, version)
);
"""

with psycopg.connect(lakebase_dsn) as conn:
    conn.execute(create_sql)
    conn.commit()

config["lakebase_host"] = LAKEBASE_HOST or instance.read_write_dns
config["lakebase_db"] = LAKEBASE_DB
config["registry_schema"] = REGISTRY_SCHEMA
config_path.write_text(yaml.safe_dump(config, sort_keys=False), encoding="utf-8")

print("Created Lakebase tables.")
print("Updated config.yaml with lakebase_host and lakebase_db.")
# Out:
# Created Lakebase tables.
# Updated config.yaml with lakebase_host and lakebase_db.

# %%
def _slugify(value: str) -> str:
    value = value.strip().lower()
    value = re.sub(r"[^a-z0-9]+", "-", value)
    return value.strip("-") or "agent"

endpoints = list(w.serving_endpoints.list())

agents_seed = []
if endpoints:
    for endpoint in endpoints:
        name = endpoint.name
        agents_seed.append(
            {
                "agent_id": _slugify(name),
                "name": name,
                "description": f"Serving endpoint {name}",
                "owner": getattr(endpoint, "creator", None),
                "status": getattr(endpoint, "state", None),
                "version": "v1",
                "mcp_server_url": DEFAULT_MCP_SERVER_URL,
                "llm_endpoint_name": name,
                "system_prompt": config.get("default_system_prompt"),
                "card": {
                    "name": name,
                    "description": f"A2A wrapper for {name}",
                    "url": A2A_BASE_URL,
                    "version": "1.0.0",
                    "defaultInputModes": ["text"],
                    "defaultOutputModes": ["text"],
                    "capabilities": {"streaming": False},
                    "skills": [
                        {
                            "id": _slugify(name),
                            "name": name,
                            "description": f"Gateway to {name}",
                            "tags": ["serving-endpoint"],
                            "examples": ["Example request"],
                        }
                    ],
                },
            }
        )
else:
    agents_seed.append(
        {
            "agent_id": "example-agent",
            "name": "example-agent",
            "description": "Example agent (no serving endpoints discovered)",
            "owner": None,
            "status": "unknown",
            "version": "v1",
            "mcp_server_url": DEFAULT_MCP_SERVER_URL,
            "llm_endpoint_name": config.get("default_llm_endpoint"),
            "system_prompt": config.get("default_system_prompt"),
            "card": {
                "name": "example-agent",
                "description": "Example A2A agent card",
                "url": A2A_BASE_URL,
                "version": "1.0.0",
                "defaultInputModes": ["text"],
                "defaultOutputModes": ["text"],
                "capabilities": {"streaming": False},
                "skills": [
                    {
                        "id": "example-agent",
                        "name": "example-agent",
                        "description": "Example skill",
                        "tags": ["example"],
                        "examples": ["Example request"],
                    }
                ],
            },
        }
    )

insert_agents = f"""
INSERT INTO {REGISTRY_SCHEMA}.agents (
    agent_id, name, description, owner, status, default_version
) VALUES (
    %(agent_id)s, %(name)s, %(description)s, %(owner)s, %(status)s, %(version)s
)
ON CONFLICT (agent_id) DO UPDATE SET
    name = EXCLUDED.name,
    description = EXCLUDED.description,
    owner = EXCLUDED.owner,
    status = EXCLUDED.status,
    default_version = EXCLUDED.default_version,
    updated_at = now();
"""

insert_versions = f"""
INSERT INTO {REGISTRY_SCHEMA}.agent_versions (
    agent_id, version, mcp_server_url, llm_endpoint_name, system_prompt, tags
) VALUES (
    %(agent_id)s, %(version)s, %(mcp_server_url)s, %(llm_endpoint_name)s,
    %(system_prompt)s, %(tags)s
)
ON CONFLICT (agent_id, version) DO UPDATE SET
    mcp_server_url = EXCLUDED.mcp_server_url,
    llm_endpoint_name = EXCLUDED.llm_endpoint_name,
    system_prompt = EXCLUDED.system_prompt,
    tags = EXCLUDED.tags,
    updated_at = now();
"""

insert_cards = f"""
INSERT INTO {REGISTRY_SCHEMA}.agent_protocol_cards (
    agent_id, version, protocol, card_json
) VALUES (
    %(agent_id)s, %(version)s, %(protocol)s, %(card_json)s
)
ON CONFLICT (agent_id, version, protocol) DO UPDATE SET
    card_json = EXCLUDED.card_json,
    updated_at = now();
"""

# %%
agents_seed
# Out:
# [{'agent_id': 'adrian-tompkins-fe-model-serving-endpoint',
#   'name': 'adrian_tompkins-fe_model-serving-endpoint',
#   'description': 'Serving endpoint adrian_tompkins-fe_model-serving-endpoint',
#   'owner': 'adrian.tompkins@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'adrian_tompkins-fe_model-serving-endpoint',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'adrian_tompkins-fe_model-serving-endpoint',
#    'description': 'A2A wrapper for adrian_tompkins-fe_model-serving-endpoint',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'adrian-tompkins-fe-model-serving-endpoint',
#      'name': 'adrian_tompkins-fe_model-serving-endpoint',
#      'description': 'Gateway to adrian_tompkins-fe_model-serving-endpoint',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'adrian-tompkins-si-model-serving-endpoint',
#   'name': 'adrian_tompkins-si_model-serving-endpoint',
#   'description': 'Serving endpoint adrian_tompkins-si_model-serving-endpoint',
#   'owner': 'adrian.tompkins@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'adrian_tompkins-si_model-serving-endpoint',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'adrian_tompkins-si_model-serving-endpoint',
#    'description': 'A2A wrapper for adrian_tompkins-si_model-serving-endpoint',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'adrian-tompkins-si-model-serving-endpoint',
#      'name': 'adrian_tompkins-si_model-serving-endpoint',
#      'description': 'Gateway to adrian_tompkins-si_model-serving-endpoint',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'advanced-mlops-churn-vladimircristea',
#   'name': 'advanced_mlops_churn_vladimircristea',
#   'description': 'Serving endpoint advanced_mlops_churn_vladimircristea',
#   'owner': 'vladimir.cristea@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'advanced_mlops_churn_vladimircristea',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'advanced_mlops_churn_vladimircristea',
#    'description': 'A2A wrapper for advanced_mlops_churn_vladimircristea',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'advanced-mlops-churn-vladimircristea',
#      'name': 'advanced_mlops_churn_vladimircristea',
#      'description': 'Gateway to advanced_mlops_churn_vladimircristea',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-aman-ps-catalog-tvs-agent-schema-aman-tvs-pdf-agent',
#   'name': 'agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#   'description': 'Serving endpoint agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#   'owner': 'aman.bansal@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#    'description': 'A2A wrapper for agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-aman-ps-catalog-tvs-agent-schema-aman-tvs-pdf-agent',
#      'name': 'agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#      'description': 'Gateway to agents_aman_ps_catalog-tvs_agent_schema-aman_tvs_pdf_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-arana-ops-domain-iot-turbine-field-ops-agent',
#   'name': 'agents_arana_ops_domain-iot_turbine-field_ops_agent',
#   'description': 'Serving endpoint agents_arana_ops_domain-iot_turbine-field_ops_agent',
#   'owner': 'rafael.arana@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_arana_ops_domain-iot_turbine-field_ops_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_arana_ops_domain-iot_turbine-field_ops_agent',
#    'description': 'A2A wrapper for agents_arana_ops_domain-iot_turbine-field_ops_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-arana-ops-domain-iot-turbine-field-ops-agent',
#      'name': 'agents_arana_ops_domain-iot_turbine-field_ops_agent',
#      'description': 'Gateway to agents_arana_ops_domain-iot_turbine-field_ops_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-cmeg-genai-content-solacc-mktg-content-generator',
#   'name': 'agents_cmeg_genai-content_solacc-mktg_content_generator',
#   'description': 'Serving endpoint agents_cmeg_genai-content_solacc-mktg_content_generator',
#   'owner': 'max.fisher@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_cmeg_genai-content_solacc-mktg_content_generator',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_cmeg_genai-content_solacc-mktg_content_generator',
#    'description': 'A2A wrapper for agents_cmeg_genai-content_solacc-mktg_content_generator',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-cmeg-genai-content-solacc-mktg-content-generator',
#      'name': 'agents_cmeg_genai-content_solacc-mktg_content_generator',
#      'description': 'Gateway to agents_cmeg_genai-content_solacc-mktg_content_generator',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-danielyanez-catalog-returns-agent-returns-agent-model',
#   'name': 'agents_danielyanez_catalog-returns_agent-returns_agent_model',
#   'description': 'Serving endpoint agents_danielyanez_catalog-returns_agent-returns_agent_model',
#   'owner': 'daniel.yanez@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_danielyanez_catalog-returns_agent-returns_agent_model',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_danielyanez_catalog-returns_agent-returns_agent_model',
#    'description': 'A2A wrapper for agents_danielyanez_catalog-returns_agent-returns_agent_model',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-danielyanez-catalog-returns-agent-returns-agent-model',
#      'name': 'agents_danielyanez_catalog-returns_agent-returns_agent_model',
#      'description': 'Gateway to agents_danielyanez_catalog-returns_agent-returns_agent_model',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-databricks-workshop-jywu-multi-agent',
#   'name': 'agents_databricks_workshop-jywu-multi_agent',
#   'description': 'Serving endpoint agents_databricks_workshop-jywu-multi_agent',
#   'owner': 'jiayi.wu@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_databricks_workshop-jywu-multi_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_databricks_workshop-jywu-multi_agent',
#    'description': 'A2A wrapper for agents_databricks_workshop-jywu-multi_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-databricks-workshop-jywu-multi-agent',
#      'name': 'agents_databricks_workshop-jywu-multi_agent',
#      'description': 'Gateway to agents_databricks_workshop-jywu-multi_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-databricks-workshop-jywu-single-agent-with-mcp',
#   'name': 'agents_databricks_workshop-jywu-single_agent_with_mcp',
#   'description': 'Serving endpoint agents_databricks_workshop-jywu-single_agent_with_mcp',
#   'owner': 'jiayi.wu@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_databricks_workshop-jywu-single_agent_with_mcp',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_databricks_workshop-jywu-single_agent_with_mcp',
#    'description': 'A2A wrapper for agents_databricks_workshop-jywu-single_agent_with_mcp',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-databricks-workshop-jywu-single-agent-with-mcp',
#      'name': 'agents_databricks_workshop-jywu-single_agent_with_mcp',
#      'description': 'Gateway to agents_databricks_workshop-jywu-single_agent_with_mcp',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-dbdemos-skr-cmgr-cmgr-agent',
#   'name': 'agents_dbdemos_skr-cmgr-cmgr_agent',
#   'description': 'Serving endpoint agents_dbdemos_skr-cmgr-cmgr_agent',
#   'owner': 'srikanthkumar.rana@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_dbdemos_skr-cmgr-cmgr_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_dbdemos_skr-cmgr-cmgr_agent',
#    'description': 'A2A wrapper for agents_dbdemos_skr-cmgr-cmgr_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-dbdemos-skr-cmgr-cmgr-agent',
#      'name': 'agents_dbdemos_skr-cmgr-cmgr_agent',
#      'description': 'Gateway to agents_dbdemos_skr-cmgr-cmgr_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-gireesh-catalog-fe-testing-market-intelligence-agent-v3',
#   'name': 'agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#   'description': 'Serving endpoint agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#   'owner': 'gireesh.sreedhar@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#    'description': 'A2A wrapper for agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-gireesh-catalog-fe-testing-market-intelligence-agent-v3',
#      'name': 'agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#      'description': 'Gateway to agents_gireesh_catalog-fe_testing-market_intelligence_agent_v3',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-gopi-llm-trip-planner-model',
#   'name': 'agents_gopi-llm-trip_planner_model',
#   'description': 'Serving endpoint agents_gopi-llm-trip_planner_model',
#   'owner': 'gopinath.chandrasekaran@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_gopi-llm-trip_planner_model',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_gopi-llm-trip_planner_model',
#    'description': 'A2A wrapper for agents_gopi-llm-trip_planner_model',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-gopi-llm-trip-planner-model',
#      'name': 'agents_gopi-llm-trip_planner_model',
#      'description': 'Gateway to agents_gopi-llm-trip_planner_model',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-himanshu-ford-dealers-documents-ford-finance-analysis',
#   'name': 'agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#   'description': 'Serving endpoint agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#   'owner': 'himanshu.gupta@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#    'description': 'A2A wrapper for agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-himanshu-ford-dealers-documents-ford-finance-analysis',
#      'name': 'agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#      'description': 'Gateway to agents_himanshu_ford_dealers-documents-ford_finance_analysis',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-hussain-jagirdar-bricksy-bricksy-copilot-agent',
#   'name': 'agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#   'description': 'Serving endpoint agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#   'owner': 'hussain.jagirdar@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#    'description': 'A2A wrapper for agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-hussain-jagirdar-bricksy-bricksy-copilot-agent',
#      'name': 'agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#      'description': 'Gateway to agents_hussain_jagirdar-bricksy-bricksy_copilot_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-hussain-jagirdar-mahindra-n-mahindra-yolo-telltale-with',
#   'name': 'agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#   'description': 'Serving endpoint agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#   'owner': 'hussain.jagirdar@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#    'description': 'A2A wrapper for agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-hussain-jagirdar-mahindra-n-mahindra-yolo-telltale-with',
#      'name': 'agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#      'description': 'Gateway to agents_hussain_jagirdar-mahindra_n_mahindra-yolo_telltale_with',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-jessyca-demos-ai-agent-bank-jessyca-agent-bank',
#   'name': 'agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#   'description': 'Serving endpoint agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#   'owner': 'jessyca.oliveira@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#    'description': 'A2A wrapper for agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-jessyca-demos-ai-agent-bank-jessyca-agent-bank',
#      'name': 'agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#      'description': 'Gateway to agents_jessyca_demos-ai_agent_bank-jessyca_agent_bank',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-malay-demo-cpg-sc-category-insights-hackathon',
#   'name': 'agents_malay_demo-cpg_sc-category_insights_hackathon',
#   'description': 'Serving endpoint agents_malay_demo-cpg_sc-category_insights_hackathon',
#   'owner': 'malay.panigrahi@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_malay_demo-cpg_sc-category_insights_hackathon',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_malay_demo-cpg_sc-category_insights_hackathon',
#    'description': 'A2A wrapper for agents_malay_demo-cpg_sc-category_insights_hackathon',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-malay-demo-cpg-sc-category-insights-hackathon',
#      'name': 'agents_malay_demo-cpg_sc-category_insights_hackathon',
#      'description': 'Gateway to agents_malay_demo-cpg_sc-category_insights_hackathon',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-malay-demo-logistics-logistics-control-tower-agent-1',
#   'name': 'agents_malay_demo-logistics-logistics_control_tower_agent_1',
#   'description': 'Serving endpoint agents_malay_demo-logistics-logistics_control_tower_agent_1',
#   'owner': 'sashank.kotta@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_malay_demo-logistics-logistics_control_tower_agent_1',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_malay_demo-logistics-logistics_control_tower_agent_1',
#    'description': 'A2A wrapper for agents_malay_demo-logistics-logistics_control_tower_agent_1',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-malay-demo-logistics-logistics-control-tower-agent-1',
#      'name': 'agents_malay_demo-logistics-logistics_control_tower_agent_1',
#      'description': 'Gateway to agents_malay_demo-logistics-logistics_control_tower_agent_1',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-malay-demo-procurement-procurement-bot-v3',
#   'name': 'agents_malay_demo-procurement-procurement_bot_v3',
#   'description': 'Serving endpoint agents_malay_demo-procurement-procurement_bot_v3',
#   'owner': 'puneet.jain@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_malay_demo-procurement-procurement_bot_v3',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_malay_demo-procurement-procurement_bot_v3',
#    'description': 'A2A wrapper for agents_malay_demo-procurement-procurement_bot_v3',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-malay-demo-procurement-procurement-bot-v3',
#      'name': 'agents_malay_demo-procurement-procurement_bot_v3',
#      'description': 'Gateway to agents_malay_demo-procurement-procurement_bot_v3',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-marion-test-agentic-ai-marion-jjg',
#   'name': 'agents_marion_test-agentic_ai_marion-JJG',
#   'description': 'Serving endpoint agents_marion_test-agentic_ai_marion-JJG',
#   'owner': 'marion.lamoureux@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_marion_test-agentic_ai_marion-JJG',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_marion_test-agentic_ai_marion-JJG',
#    'description': 'A2A wrapper for agents_marion_test-agentic_ai_marion-JJG',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-marion-test-agentic-ai-marion-jjg',
#      'name': 'agents_marion_test-agentic_ai_marion-JJG',
#      'description': 'Gateway to agents_marion_test-agentic_ai_marion-JJG',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-merve-karali-travel-agents-train-travel-agent',
#   'name': 'agents_merve_karali-travel_agents-train_travel_agent',
#   'description': 'Serving endpoint agents_merve_karali-travel_agents-train_travel_agent',
#   'owner': 'merve.karali@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_merve_karali-travel_agents-train_travel_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_merve_karali-travel_agents-train_travel_agent',
#    'description': 'A2A wrapper for agents_merve_karali-travel_agents-train_travel_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-merve-karali-travel-agents-train-travel-agent',
#      'name': 'agents_merve_karali-travel_agents-train_travel_agent',
#      'description': 'Gateway to agents_merve_karali-travel_agents-train_travel_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-mervekarali-catalog-mb-mlflow-agent-model',
#   'name': 'agents_mervekarali_catalog-mb_mlflow-agent_model',
#   'description': 'Serving endpoint agents_mervekarali_catalog-mb_mlflow-agent_model',
#   'owner': 'merve.karali@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_mervekarali_catalog-mb_mlflow-agent_model',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_mervekarali_catalog-mb_mlflow-agent_model',
#    'description': 'A2A wrapper for agents_mervekarali_catalog-mb_mlflow-agent_model',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-mervekarali-catalog-mb-mlflow-agent-model',
#      'name': 'agents_mervekarali_catalog-mb_mlflow-agent_model',
#      'description': 'Gateway to agents_mervekarali_catalog-mb_mlflow-agent_model',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-miguel-peralvo-demos-agents-product-agent',
#   'name': 'agents_miguel_peralvo_demos-agents-product_agent',
#   'description': 'Serving endpoint agents_miguel_peralvo_demos-agents-product_agent',
#   'owner': 'miguel.peralvo@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.NOT_READY: 'NOT_READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_miguel_peralvo_demos-agents-product_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_miguel_peralvo_demos-agents-product_agent',
#    'description': 'A2A wrapper for agents_miguel_peralvo_demos-agents-product_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-miguel-peralvo-demos-agents-product-agent',
#      'name': 'agents_miguel_peralvo_demos-agents-product_agent',
#      'description': 'Gateway to agents_miguel_peralvo_demos-agents-product_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-natyra-demo-mlflow3-getting-started-agent',
#   'name': 'agents_natyra_demo-mlflow3-getting_started_agent',
#   'description': 'Serving endpoint agents_natyra_demo-mlflow3-getting_started_agent',
#   'owner': 'natyra.bajraktari@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_natyra_demo-mlflow3-getting_started_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_natyra_demo-mlflow3-getting_started_agent',
#    'description': 'A2A wrapper for agents_natyra_demo-mlflow3-getting_started_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-natyra-demo-mlflow3-getting-started-agent',
#      'name': 'agents_natyra_demo-mlflow3-getting_started_agent',
#      'description': 'Gateway to agents_natyra_demo-mlflow3-getting_started_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-psalm-penn-med-sql-agent',
#   'name': 'agents_psalm-penn_med-sql_agent',
#   'description': 'Serving endpoint agents_psalm-penn_med-sql_agent',
#   'owner': 'phil.salm@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_psalm-penn_med-sql_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_psalm-penn_med-sql_agent',
#    'description': 'A2A wrapper for agents_psalm-penn_med-sql_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-psalm-penn-med-sql-agent',
#      'name': 'agents_psalm-penn_med-sql_agent',
#      'description': 'Gateway to agents_psalm-penn_med-sql_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-rebecca-nissan-mimic-iii-clinical-assistant',
#   'name': 'agents_rebecca_nissan-mimic_iii-clinical_assistant',
#   'description': 'Serving endpoint agents_rebecca_nissan-mimic_iii-clinical_assistant',
#   'owner': 'rebecca.nissan@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_rebecca_nissan-mimic_iii-clinical_assistant',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_rebecca_nissan-mimic_iii-clinical_assistant',
#    'description': 'A2A wrapper for agents_rebecca_nissan-mimic_iii-clinical_assistant',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-rebecca-nissan-mimic-iii-clinical-assistant',
#      'name': 'agents_rebecca_nissan-mimic_iii-clinical_assistant',
#      'description': 'Gateway to agents_rebecca_nissan-mimic_iii-clinical_assistant',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-rfrausto-agent-bricks-demo-product-agent',
#   'name': 'agents_rfrausto-agent_bricks_demo-product_agent',
#   'description': 'Serving endpoint agents_rfrausto-agent_bricks_demo-product_agent',
#   'owner': 'rick.frausto@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_rfrausto-agent_bricks_demo-product_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_rfrausto-agent_bricks_demo-product_agent',
#    'description': 'A2A wrapper for agents_rfrausto-agent_bricks_demo-product_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-rfrausto-agent-bricks-demo-product-agent',
#      'name': 'agents_rfrausto-agent_bricks_demo-product_agent',
#      'description': 'Gateway to agents_rfrausto-agent_bricks_demo-product_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-rodrigo-default-lakehouse-memory-agent',
#   'name': 'agents_rodrigo-default-lakehouse-memory-agent',
#   'description': 'Serving endpoint agents_rodrigo-default-lakehouse-memory-agent',
#   'owner': 'rodrigo.perez@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_rodrigo-default-lakehouse-memory-agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_rodrigo-default-lakehouse-memory-agent',
#    'description': 'A2A wrapper for agents_rodrigo-default-lakehouse-memory-agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-rodrigo-default-lakehouse-memory-agent',
#      'name': 'agents_rodrigo-default-lakehouse-memory-agent',
#      'description': 'Gateway to agents_rodrigo-default-lakehouse-memory-agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-rodrigo-se-iberia-supervisor-iberia',
#   'name': 'agents_rodrigo-se_iberia-supervisor_iberia',
#   'description': 'Serving endpoint agents_rodrigo-se_iberia-supervisor_iberia',
#   'owner': 'rodrigo.perez@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_rodrigo-se_iberia-supervisor_iberia',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_rodrigo-se_iberia-supervisor_iberia',
#    'description': 'A2A wrapper for agents_rodrigo-se_iberia-supervisor_iberia',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-rodrigo-se-iberia-supervisor-iberia',
#      'name': 'agents_rodrigo-se_iberia-supervisor_iberia',
#      'description': 'Gateway to agents_rodrigo-se_iberia-supervisor_iberia',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-ronguerrero-default-agent-model',
#   'name': 'agents_ronguerrero-default-agent_model',
#   'description': 'Serving endpoint agents_ronguerrero-default-agent_model',
#   'owner': 'ron.guerrero@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_ronguerrero-default-agent_model',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_ronguerrero-default-agent_model',
#    'description': 'A2A wrapper for agents_ronguerrero-default-agent_model',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-ronguerrero-default-agent-model',
#      'name': 'agents_ronguerrero-default-agent_model',
#      'description': 'Gateway to agents_ronguerrero-default-agent_model',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-saiyang-dbdemos-mb-community-event-sql-agent',
#   'name': 'agents_saiyang_dbdemos-mb_community_event-sql_agent',
#   'description': 'Serving endpoint agents_saiyang_dbdemos-mb_community_event-sql_agent',
#   'owner': 'sai.yang@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_saiyang_dbdemos-mb_community_event-sql_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_saiyang_dbdemos-mb_community_event-sql_agent',
#    'description': 'A2A wrapper for agents_saiyang_dbdemos-mb_community_event-sql_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-saiyang-dbdemos-mb-community-event-sql-agent',
#      'name': 'agents_saiyang_dbdemos-mb_community_event-sql_agent',
#      'description': 'Gateway to agents_saiyang_dbdemos-mb_community_event-sql_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-sarbanimaiti-catalog-rag-agent-financial-analyst-rag-age',
#   'name': 'agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#   'description': 'Serving endpoint agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#   'owner': 'sarbani.maiti@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#    'description': 'A2A wrapper for agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-sarbanimaiti-catalog-rag-agent-financial-analyst-rag-age',
#      'name': 'agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#      'description': 'Gateway to agents_sarbanimaiti_catalog-rag_agent-financial_analyst_rag_age',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-sash-catalog-sash-demo-category-insights-hackathon',
#   'name': 'agents_sash_catalog-sash_demo-category_insights_hackathon',
#   'description': 'Serving endpoint agents_sash_catalog-sash_demo-category_insights_hackathon',
#   'owner': 'sashank.kotta@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_sash_catalog-sash_demo-category_insights_hackathon',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_sash_catalog-sash_demo-category_insights_hackathon',
#    'description': 'A2A wrapper for agents_sash_catalog-sash_demo-category_insights_hackathon',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-sash-catalog-sash-demo-category-insights-hackathon',
#      'name': 'agents_sash_catalog-sash_demo-category_insights_hackathon',
#      'description': 'Gateway to agents_sash_catalog-sash_demo-category_insights_hackathon',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-shm-3w-well-agent',
#   'name': 'agents_shm-3w-well_agent',
#   'description': 'Serving endpoint agents_shm-3w-well_agent',
#   'owner': 'scott.mckean@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_shm-3w-well_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_shm-3w-well_agent',
#    'description': 'A2A wrapper for agents_shm-3w-well_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-shm-3w-well-agent',
#      'name': 'agents_shm-3w-well_agent',
#      'description': 'Gateway to agents_shm-3w-well_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-somesh-sharma-demo-pdm-pdm-langgraph-agent',
#   'name': 'agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#   'description': 'Serving endpoint agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#   'owner': '14721e4d-0456-4784-9ec4-c245efab77d6',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#    'description': 'A2A wrapper for agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-somesh-sharma-demo-pdm-pdm-langgraph-agent',
#      'name': 'agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#      'description': 'Gateway to agents_somesh_sharma_demo-pdm-pdm_langgraph_agent',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-tetan-demo-train-agent-train-assistant',
#   'name': 'agents_tetan_demo-train_agent-train_assistant',
#   'description': 'Serving endpoint agents_tetan_demo-train_agent-train_assistant',
#   'owner': 'te.tan@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_tetan_demo-train_agent-train_assistant',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_tetan_demo-train_agent-train_assistant',
#    'description': 'A2A wrapper for agents_tetan_demo-train_agent-train_assistant',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-tetan-demo-train-agent-train-assistant',
#      'name': 'agents_tetan_demo-train_agent-train_assistant',
#      'description': 'Gateway to agents_tetan_demo-train_agent-train_assistant',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-thales-ife-main-gena-ife-agent-bis',
#   'name': 'agents_thales_ife-main-gena-ife-agent-bis',
#   'description': 'Serving endpoint agents_thales_ife-main-gena-ife-agent-bis',
#   'owner': 'amine.charifi@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.NOT_READY: 'NOT_READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_thales_ife-main-gena-ife-agent-bis',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_thales_ife-main-gena-ife-agent-bis',
#    'description': 'A2A wrapper for agents_thales_ife-main-gena-ife-agent-bis',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-thales-ife-main-gena-ife-agent-bis',
#      'name': 'agents_thales_ife-main-gena-ife-agent-bis',
#      'description': 'Gateway to agents_thales_ife-main-gena-ife-agent-bis',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-thales-ags-mro-ags-mro-agent-4',
#   'name': 'agents_thales-ags_mro-ags-mro-agent-4',
#   'description': 'Serving endpoint agents_thales-ags_mro-ags-mro-agent-4',
#   'owner': 'amine.charifi@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_thales-ags_mro-ags-mro-agent-4',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_thales-ags_mro-ags-mro-agent-4',
#    'description': 'A2A wrapper for agents_thales-ags_mro-ags-mro-agent-4',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-thales-ags-mro-ags-mro-agent-4',
#      'name': 'agents_thales-ags_mro-ags-mro-agent-4',
#      'description': 'Gateway to agents_thales-ags_mro-ags-mro-agent-4',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-tom-magelinski-dbdemos-ai-agent-dbdemos-ai-agent-w-genie',
#   'name': 'agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#   'description': 'Serving endpoint agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#   'owner': 'tom.magelinski@databricks.com',
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#    'description': 'A2A wrapper for agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'agents-tom-magelinski-dbdemos-ai-agent-dbdemos-ai-agent-w-genie',
#      'name': 'agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#      'description': 'Gateway to agents_tom_magelinski-dbdemos_ai_agent-dbdemos_ai_agent_w_genie',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'agents-users-jose-silva-rfxautomation',
#   'name': 'agents_users-jose_silva-rfxautomation',
# ...
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-llama-4-maverick',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-llama-4-maverick',
#    'description': 'A2A wrapper for databricks-llama-4-maverick',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-llama-4-maverick',
#      'name': 'databricks-llama-4-maverick',
#      'description': 'Gateway to databricks-llama-4-maverick',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gemma-3-12b',
#   'name': 'databricks-gemma-3-12b',
#   'description': 'Serving endpoint databricks-gemma-3-12b',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gemma-3-12b',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gemma-3-12b',
#    'description': 'A2A wrapper for databricks-gemma-3-12b',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gemma-3-12b',
#      'name': 'databricks-gemma-3-12b',
#      'description': 'Gateway to databricks-gemma-3-12b',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gte-large-en',
#   'name': 'databricks-gte-large-en',
#   'description': 'Serving endpoint databricks-gte-large-en',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gte-large-en',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gte-large-en',
#    'description': 'A2A wrapper for databricks-gte-large-en',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gte-large-en',
#      'name': 'databricks-gte-large-en',
#      'description': 'Gateway to databricks-gte-large-en',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-bge-large-en',
#   'name': 'databricks-bge-large-en',
#   'description': 'Serving endpoint databricks-bge-large-en',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-bge-large-en',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-bge-large-en',
#    'description': 'A2A wrapper for databricks-bge-large-en',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-bge-large-en',
#      'name': 'databricks-bge-large-en',
#      'description': 'Gateway to databricks-bge-large-en',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gpt-5-1',
#   'name': 'databricks-gpt-5-1',
#   'description': 'Serving endpoint databricks-gpt-5-1',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gpt-5-1',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gpt-5-1',
#    'description': 'A2A wrapper for databricks-gpt-5-1',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gpt-5-1',
#      'name': 'databricks-gpt-5-1',
#      'description': 'Gateway to databricks-gpt-5-1',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gpt-5',
#   'name': 'databricks-gpt-5',
#   'description': 'Serving endpoint databricks-gpt-5',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gpt-5',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gpt-5',
#    'description': 'A2A wrapper for databricks-gpt-5',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gpt-5',
#      'name': 'databricks-gpt-5',
#      'description': 'Gateway to databricks-gpt-5',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-meta-llama-3-1-8b-instruct',
#   'name': 'databricks-meta-llama-3-1-8b-instruct',
#   'description': 'Serving endpoint databricks-meta-llama-3-1-8b-instruct',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-meta-llama-3-1-8b-instruct',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-meta-llama-3-1-8b-instruct',
#    'description': 'A2A wrapper for databricks-meta-llama-3-1-8b-instruct',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-meta-llama-3-1-8b-instruct',
#      'name': 'databricks-meta-llama-3-1-8b-instruct',
#      'description': 'Gateway to databricks-meta-llama-3-1-8b-instruct',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-meta-llama-3-3-70b-instruct',
#   'name': 'databricks-meta-llama-3-3-70b-instruct',
#   'description': 'Serving endpoint databricks-meta-llama-3-3-70b-instruct',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-meta-llama-3-3-70b-instruct',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-meta-llama-3-3-70b-instruct',
#    'description': 'A2A wrapper for databricks-meta-llama-3-3-70b-instruct',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-meta-llama-3-3-70b-instruct',
#      'name': 'databricks-meta-llama-3-3-70b-instruct',
#      'description': 'Gateway to databricks-meta-llama-3-3-70b-instruct',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gemini-2-5-flash',
#   'name': 'databricks-gemini-2-5-flash',
#   'description': 'Serving endpoint databricks-gemini-2-5-flash',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gemini-2-5-flash',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gemini-2-5-flash',
#    'description': 'A2A wrapper for databricks-gemini-2-5-flash',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gemini-2-5-flash',
#      'name': 'databricks-gemini-2-5-flash',
#      'description': 'Gateway to databricks-gemini-2-5-flash',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-gemini-2-5-pro',
#   'name': 'databricks-gemini-2-5-pro',
#   'description': 'Serving endpoint databricks-gemini-2-5-pro',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-gemini-2-5-pro',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-gemini-2-5-pro',
#    'description': 'A2A wrapper for databricks-gemini-2-5-pro',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-gemini-2-5-pro',
#      'name': 'databricks-gemini-2-5-pro',
#      'description': 'Gateway to databricks-gemini-2-5-pro',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-claude-opus-4-5',
#   'name': 'databricks-claude-opus-4-5',
#   'description': 'Serving endpoint databricks-claude-opus-4-5',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-claude-opus-4-5',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-claude-opus-4-5',
#    'description': 'A2A wrapper for databricks-claude-opus-4-5',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-claude-opus-4-5',
#      'name': 'databricks-claude-opus-4-5',
#      'description': 'Gateway to databricks-claude-opus-4-5',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-claude-opus-4-1',
#   'name': 'databricks-claude-opus-4-1',
#   'description': 'Serving endpoint databricks-claude-opus-4-1',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-claude-opus-4-1',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-claude-opus-4-1',
#    'description': 'A2A wrapper for databricks-claude-opus-4-1',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-claude-opus-4-1',
#      'name': 'databricks-claude-opus-4-1',
#      'description': 'Gateway to databricks-claude-opus-4-1',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-claude-sonnet-4',
#   'name': 'databricks-claude-sonnet-4',
#   'description': 'Serving endpoint databricks-claude-sonnet-4',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-claude-sonnet-4',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-claude-sonnet-4',
#    'description': 'A2A wrapper for databricks-claude-sonnet-4',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-claude-sonnet-4',
#      'name': 'databricks-claude-sonnet-4',
#      'description': 'Gateway to databricks-claude-sonnet-4',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-claude-3-7-sonnet',
#   'name': 'databricks-claude-3-7-sonnet',
#   'description': 'Serving endpoint databricks-claude-3-7-sonnet',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-claude-3-7-sonnet',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-claude-3-7-sonnet',
#    'description': 'A2A wrapper for databricks-claude-3-7-sonnet',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-claude-3-7-sonnet',
#      'name': 'databricks-claude-3-7-sonnet',
#      'description': 'Gateway to databricks-claude-3-7-sonnet',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-qwen3-embedding-0-6b',
#   'name': 'databricks-qwen3-embedding-0-6b',
#   'description': 'Serving endpoint databricks-qwen3-embedding-0-6b',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-qwen3-embedding-0-6b',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-qwen3-embedding-0-6b',
#    'description': 'A2A wrapper for databricks-qwen3-embedding-0-6b',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-qwen3-embedding-0-6b',
#      'name': 'databricks-qwen3-embedding-0-6b',
#      'description': 'Gateway to databricks-qwen3-embedding-0-6b',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}},
#  {'agent_id': 'databricks-meta-llama-3-1-405b-instruct',
#   'name': 'databricks-meta-llama-3-1-405b-instruct',
#   'description': 'Serving endpoint databricks-meta-llama-3-1-405b-instruct',
#   'owner': None,
#   'status': EndpointState(config_update=<EndpointStateConfigUpdate.NOT_UPDATING: 'NOT_UPDATING'>, ready=<EndpointStateReady.READY: 'READY'>),
#   'version': 'v1',
#   'mcp_server_url': 'https://<your-workspace>/api/2.0/mcp/<server-id>',
#   'llm_endpoint_name': 'databricks-meta-llama-3-1-405b-instruct',
#   'system_prompt': 'You are a helpful assistant.',
#   'card': {'name': 'databricks-meta-llama-3-1-405b-instruct',
#    'description': 'A2A wrapper for databricks-meta-llama-3-1-405b-instruct',
#    'url': '/api/a2a',
#    'version': '1.0.0',
#    'defaultInputModes': ['text'],
#    'defaultOutputModes': ['text'],
#    'capabilities': {'streaming': False},
#    'skills': [{'id': 'databricks-meta-llama-3-1-405b-instruct',
#      'name': 'databricks-meta-llama-3-1-405b-instruct',
#      'description': 'Gateway to databricks-meta-llama-3-1-405b-instruct',
#      'tags': ['serving-endpoint'],
#      'examples': ['Example request']}]}}]

# %%
with psycopg.connect(lakebase_dsn) as conn:
    for agent in agents_seed:
        payload = {
            "agent_id": agent["agent_id"],
            "name": agent["name"],
            "description": agent["description"],
            "owner": agent["owner"],
            "status": agent["status"],
            "version": agent["version"],
            "mcp_server_url": agent["mcp_server_url"],
            "llm_endpoint_name": agent["llm_endpoint_name"],
            "system_prompt": agent["system_prompt"],
            "tags": json.dumps({"source": "serving_endpoint"}),
            "protocol": "a2a",
            "card_json": json.dumps(agent["card"]),
        }
        conn.execute(insert_agents, payload)
        conn.execute(insert_versions, payload)
        conn.execute(insert_cards, payload)
    conn.commit()

print(f"Seeded {len(agents_seed)} agent records.")
